# %% [markdown]
# - build code bug-fixing SaaS application using Flask
# - use ChatGPT API to generate explanations and solutions to code errors
# - create web form that accepts user input for code and error messages
# - design web interface to display the generated explanations and solutions
# - deploy an application to Azure cloud platform
# - integrate application with WordPress website

# %% [markdown]
# # 2 key componets (to fix users' code)
# 1. Request 1: ChatGPT uses buggy code and the error to fix the code
# 2. Request 2: ChatGPT uses the buggy code adn the error to explain the error to the user in plain English

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
